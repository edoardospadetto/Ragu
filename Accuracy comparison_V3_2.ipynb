# %% [markdown]
# ## Complicated Method

# %%
data=[[0.9,0.8,0.7,0.6,0.5,0.4],[0.4616,0.4761,0.6322,0.6990,0.7355,0.7673],
      [0.9502,0.8018,0.6871,0.6367,0.5760,0.5092],
      [0.0482,0.2171,0.4968,0.8488,1.853,3.0788],
      [0.9961,0.9812,0.9554,0.9160,0.8390,0.6244]]
import matplotlib.pyplot as plt

plt.scatter(data[0],data[2])
plt.scatter(data[0],data[4])
plt.plot(data[0],data[2], label= "CNN")
plt.plot(data[0],data[4],label="LSTM")
plt.title("Accuracy comparison")
plt.ylabel("Accuracy")
plt.xlabel("P")

plt.legend()
plt.savefig("Accuracycomparison2")
plt.show()

# %% [markdown]
# ## Monte Carlo

# %%
import numpy as np
datamc = np.array(   [ 0.4,1, 1,
0.35,0.9995,0.9981,
0.3,0.9903 ,0.9819,
0.295,0.5023,0.9575,
0.27,0.4977 , 0.7637,
0.26,0.4977 , 0.5212 , 
0.25,0.4954, 0.4977])

# %%
datamc=datamc.reshape((7,3))

# %%
print(datamc)
import matplotlib.pyplot as plt
plt.scatter(datamc[:,0],datamc[:,1])
plt.scatter(datamc[:,0],datamc[:,2])
plt.plot(datamc[:,0],datamc[:,1], label= "CNN")
plt.plot(datamc[:,0],datamc[:,2],label="LSTM")
plt.ylabel("Accuracy")
plt.xlabel("P")
plt.title("Accuracy comparison: LSTM,CNN")
plt.savefig('MonteCarlo_acc_comp.png',bbox_inches='tight')
plt.legend()
plt.show()
# Out:
# [[0.4    1.     1.    ]
#  [0.35   0.9995 0.9981]
#  [0.3    0.9903 0.9819]
#  [0.295  0.5023 0.9575]
#  [0.27   0.4977 0.7637]
#  [0.26   0.4977 0.5212]
#  [0.25   0.4954 0.4977]]

# %% [markdown]
# ## Time Duration

# %%
import pandas as pd 

plt.bar( [0,1],[1765.2826516628265,74.34633564949036 ], color = ["C1", "C0"])
plt.xticks([0,1], ["LSTM", "CNN"] )  
plt.title("Time comparison: CNN,LSTM")
plt.ylabel("Training Time [s]")
plt.savefig("time_comparison_MC.png")
plt.show()
